# %% [markdown]
# # Task 1
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ###  Data Loading

# %%
df = pd.read_csv("Dataset_1.csv")

# %% [markdown]
# #### Data Samples

# %%
df.head(5)
# Out:
#       accident_id    accident_datetime        state            district  \
# 0  ACC20240000709  2024-12-15 15:14:47    Karnataka      Hubli District
# 1  ACC20200196249  2020-09-09 21:36:54      Haryana  Faridabad District
# 2  ACC20180059148  2018-07-24 16:43:57  West Bengal   Siliguri District
# 3  ACC20160076737  2016-11-17 17:53:16  West Bengal     Howrah District
# 4  ACC20230004919  2023-03-18 23:35:24    Rajasthan    Jodhpur District
#
#     area_type   latitude  longitude            road_type      road_condition  \
# 0       Rural  15.741067  74.555047        State Highway      Pothole-Ridden
# 1       Urban  30.211127  75.461897  Other District Road                 Dry
# 2  Semi-Urban  23.782972  86.281103        State Highway  Under Construction
# 3       Rural  24.872909  87.339504     National Highway                 Dry
# 4  Semi-Urban  24.305082  74.252979        State Highway                 Dry
#
#          road_lighting  ...  ambulance_called  police_called  \
# 0   Streetlight Absent  ...                No            Yes
# 1   Streetlight Absent  ...                No             No
# 2   Streetlight Absent  ...                No             No
# 3   Streetlight Absent  ...               Yes            Yes
# 4  Streetlight Present  ...                No             No
#
#    response_time_minutes hospitalization_required num_vehicles num_injuries  \
# 0              86.178166                      Yes            2            3
# 1                    NaN                       No            2            0
# 2                    NaN                       No            5            2
# 3              16.943981                       No            1            0
# 4                    NaN                       No            3            0
#
#   num_fatalities  accident_severity  insurance_claim_filed  \
# 0              1             Severe                     No
# 1              0              Minor                    Yes
# 2              0           Moderate                    Yes
# 3              0              Minor                    Yes
# 4              0              Minor                    Yes
#
#    insurance_claim_amount
# 0                     NaN
# 1                 26761.0
# 2                  9295.0
# 3                 48147.0
# 4                 20636.0
#
# [5 rows x 48 columns]

# %%
df.tail(5)
# Out:
#            accident_id    accident_datetime          state  \
# 201995  ACC20210195949  2021-04-01 20:30:23          Delhi
# 201996  ACC20250004714  2025-02-22 19:51:03      Telangana
# 201997  ACC20220041187  2022-09-17 10:30:59  Uttar Pradesh
# 201998  ACC20240117449  2024-06-23 16:17:20  Uttar Pradesh
# 201999  ACC20190162698  2019-06-17 13:21:45    Maharashtra
#
#                    district   area_type   latitude  longitude  \
# 201995  Karol Bagh District       Rural  28.856258  76.939912
# 201996    Warangal District       Urban  16.247233  80.497432
# 201997      Kanpur District       Urban  29.577508  82.371175
# 201998       Noida District  Semi-Urban  27.544344  82.830455
# 201999        Pune District       Rural  18.197268  76.646965
#
#                   road_type road_condition        road_lighting  ...  \
# 201995         Village Road            Dry  Streetlight Present  ...
# 201996         Village Road            Wet  Streetlight Present  ...
# 201997        State Highway            Wet  Streetlight Present  ...
# 201998     National Highway            Dry  Streetlight Present  ...
# 201999  Other District Road            Dry  Streetlight Present  ...
#
#         ambulance_called  police_called  response_time_minutes  \
# 201995                No             No                    NaN
# 201996                No             No                    NaN
# 201997                No            Yes               23.02214
# 201998                No             No                2.00000
# 201999               Yes            Yes               15.66270
#
#        hospitalization_required num_vehicles num_injuries num_fatalities  \
# 201995                       No            3            1              0
# 201996                      Yes            1            4              0
# 201997                       No            1            0              0
# 201998                       No            2            0              0
# 201999                       No            2            1              0
#
#         accident_severity  insurance_claim_filed  insurance_claim_amount
# 201995              Minor                    Yes                 90403.0
# 201996             Severe                    Yes                     NaN
# 201997              Minor                    Yes                 20274.0
# 201998              Minor                    Yes                 63623.0
# 201999           Moderate                     No                     NaN
#
# [5 rows x 48 columns]

# %%
df.sample(5)
# Out:
#            accident_id    accident_datetime           state  \
# 169178  ACC20230062006  2023-01-24 19:57:28         Gujarat
# 133745  ACC20260010733  2026-03-31 14:42:05          Kerala
# 182401  ACC20200070860  2020-08-13 11:34:29  Madhya Pradesh
# 156864  ACC20210030970  2021-07-20 08:07:18     West Bengal
# 97421   ACC20170058054  2017-12-22 14:39:52         Haryana
#
#                            district   area_type   latitude  longitude  \
# 169178              Rajkot District  Semi-Urban  23.727403  71.697999
# 133745  Thiruvananthapuram District  Semi-Urban   9.909038  74.654790
# 182401            Jabalpur District       Rural  21.313097  77.238927
# 156864            Durgapur District       Rural  23.713794  86.970802
# 97421              Panipat District  Semi-Urban  29.087659  77.033685
#
#                road_type      road_condition       road_lighting  ...  \
# 169178      Village Road                 Wet  Streetlight Absent  ...
# 133745     State Highway                 Dry  Streetlight Absent  ...
# 182401  National Highway                 Dry  Streetlight Absent  ...
# 156864      Village Road  Under Construction  Streetlight Absent  ...
# 97421      State Highway                 Dry  Streetlight Absent  ...
#
#         ambulance_called  police_called  response_time_minutes  \
# 169178                No             No                    NaN
# 133745                No             No                    NaN
# 182401               Yes             No              56.433410
# 156864               Yes            Yes              44.545097
# 97421                Yes            Yes              20.080457
#
#        hospitalization_required num_vehicles num_injuries num_fatalities  \
# 169178                       No            3            0              0
# 133745                      NaN            1            0              0
# 182401                       No            2            2              0
# 156864                       No            3            4              2
# 97421                       Yes            4            3              1
#
#         accident_severity  insurance_claim_filed  insurance_claim_amount
# 169178              Minor                    Yes                 27136.0
# 133745              Minor         Not Applicable                     NaN
# 182401           Moderate                    Yes                 40485.0
# 156864             Severe                    Yes                  5619.0
# 97421               Fatal                     No                     NaN
#
# [5 rows x 48 columns]

# %% [markdown]
# ### Dataset info

# %%
df.size
# Out:
# 9696000

# %%
print(df.shape)
print("Rows:",df.shape[0])
print("Columns:",df.shape[1])
# Out:
# (202000, 48)
# Rows: 202000
# Columns: 48

# %%
df.columns
# Out:
# Index(['accident_id', 'accident_datetime', 'state', 'district', 'area_type',
#        'latitude', 'longitude', 'road_type', 'road_condition', 'road_lighting',
#        'number_of_lanes', 'speed_limit_kmph', 'estimated_speed_kmph',
#        'junction_type', 'traffic_signal_present', 'median_present',
#        'weather_condition', 'visibility_km', 'temperature_c', 'rainfall_mm',
#        'driver_age', 'driver_gender', 'driving_experience_years',
#        'license_status', 'alcohol_involved', 'distraction_involved',
#        'mobile_phone_used', 'fatigue_involved', 'helmet_seatbelt_used',
#        'vehicle_type', 'vehicle_age_years', 'vehicle_brand', 'vehicle_model',
#        'vehicle_condition', 'overloading_status', 'primary_cause',
#        'secondary_cause', 'emergency_services_called', 'ambulance_called',
#        'police_called', 'response_time_minutes', 'hospitalization_required',
#        'num_vehicles', 'num_injuries', 'num_fatalities', 'accident_severity',
#        'insurance_claim_filed', 'insurance_claim_amount'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 202000 entries, 0 to 201999
# Data columns (total 48 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   accident_id                202000 non-null  str
#  1   accident_datetime          202000 non-null  str
#  2   state                      202000 non-null  str
#  3   district                   195938 non-null  str
#  4   area_type                  202000 non-null  str
#  5   latitude                   192022 non-null  float64
#  6   longitude                  192022 non-null  float64
#  7   road_type                  202000 non-null  str
#  8   road_condition             202000 non-null  str
#  9   road_lighting              195936 non-null  str
#  10  number_of_lanes            193914 non-null  float64
#  11  speed_limit_kmph           191888 non-null  float64
#  12  estimated_speed_kmph       202000 non-null  float64
#  13  junction_type              195935 non-null  str
#  14  traffic_signal_present     193937 non-null  str
#  15  median_present             193931 non-null  str
#  16  weather_condition          197962 non-null  str
#  17  visibility_km              189879 non-null  float64
#  18  temperature_c              191903 non-null  float64
#  19  rainfall_mm                202000 non-null  float64
#  20  driver_age                 173756 non-null  float64
#  21  driver_gender              195942 non-null  str
#  22  driving_experience_years   173756 non-null  float64
#  23  license_status             202000 non-null  str
#  24  alcohol_involved           202000 non-null  str
#  25  distraction_involved       202000 non-null  str
#  26  mobile_phone_used          202000 non-null  str
#  27  fatigue_involved           202000 non-null  str
#  28  helmet_seatbelt_used       202000 non-null  str
#  29  vehicle_type               202000 non-null  str
#  30  vehicle_age_years          173756 non-null  float64
#  31  vehicle_brand              163334 non-null  str
#  32  vehicle_model              158059 non-null  str
#  33  vehicle_condition          202000 non-null  str
#  34  overloading_status         191891 non-null  str
#  35  primary_cause              202000 non-null  str
#  36  secondary_cause            62925 non-null   str
#  37  emergency_services_called  202000 non-null  str
#  38  ambulance_called           202000 non-null  str
#  39  police_called              202000 non-null  str
#  40  response_time_minutes      96227 non-null   float64
#  41  hospitalization_required   193928 non-null  str
#  42  num_vehicles               202000 non-null  int64
#  43  num_injuries               202000 non-null  int64
#  44  num_fatalities             202000 non-null  int64
#  45  accident_severity          202000 non-null  str
#  46  insurance_claim_filed      202000 non-null  str
#  47  insurance_claim_amount     91096 non-null   float64
# dtypes: float64(13), int64(3), str(32)
# memory usage: 119.3 MB

# %% [markdown]
# #### Statistical Information

# %%
df.describe()
# Out:
#             latitude      longitude  number_of_lanes  speed_limit_kmph  \
# count  192022.000000  192022.000000     193914.00000     191888.000000
# mean       21.762030      77.979976          2.84785         58.830516
# std         8.743458      15.193053          1.42158         23.129471
# min       -89.993206    -179.316379          1.00000         20.000000
# 25%        17.832292      75.580903          2.00000         40.000000
# 50%        23.361621      77.912843          2.00000         60.000000
# 75%        26.645448      82.083551          4.00000         70.000000
# max        89.967149     179.807326          6.00000        120.000000
#
#        estimated_speed_kmph  visibility_km  temperature_c    rainfall_mm  \
# count         202000.000000  189879.000000  191903.000000  202000.000000
# mean              61.670709       4.912759      22.199841       3.488586
# std               29.602714       2.851291       8.149343      10.438514
# min                5.000000       0.020000       2.000000       0.000000
# 25%               39.900000       2.660000      15.600000       0.000000
# 50%               57.300000       4.710000      22.300000       0.000000
# 75%               78.200000       7.360000      28.800000       0.000000
# max              160.000000      10.850000      47.000000     252.100000
#
#           driver_age  driving_experience_years  vehicle_age_years  \
# count  173756.000000             173756.000000      173756.000000
# mean       36.482193                 16.723268           5.482622
# std        12.820925                 11.906786           5.392957
# min        13.000000                  0.000000           0.000000
# 25%        27.000000                  7.100000           1.600000
# 50%        36.000000                 16.000000           3.800000
# 75%        45.000000                 24.900000           7.600000
# max       102.000000                 55.000000          30.000000
#
#        response_time_minutes   num_vehicles   num_injuries  num_fatalities  \
# count           96227.000000  202000.000000  202000.000000   202000.000000
# mean               21.916837       2.536163       1.083762        0.120337
# std                19.077603       1.456641       1.401991        0.531508
# min                 2.000000       1.000000       0.000000       -1.000000
# 25%                 7.348077       2.000000       0.000000        0.000000
# 50%                17.658348       2.000000       1.000000        0.000000
# 75%                30.049904       3.000000       2.000000        0.000000
# max               180.000000      24.000000      13.000000       15.000000
#
#        insurance_claim_amount
# count            91096.000000
# mean             41097.798465
# std              38272.018771
# min               3000.000000
# 25%              13899.750000
# 50%              29458.500000
# 75%              55813.500000
# max             434334.000000

# %%
df.describe(include="object")
# Out:
# /var/folders/44/fywnm5sj335fdzvrq6s4_m3c0000gn/T/ipykernel_3507/702825166.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include="object")
#            accident_id    accident_datetime          state         district  \
# count           202000               202000         202000           195938
# unique          200000               199922             21               87
# top     ACC20150003462  2015-10-20 10:01:09  Uttar Pradesh  Kanpur District
# freq                 3                    3          28779             4728
#
#        area_type            road_type road_condition        road_lighting  \
# count     202000               202000         202000               195936
# unique         3                   20              5                    2
# top        Urban  Other District Road            Dry  Streetlight Present
# freq       91077                54235         125097               117476
#
#        junction_type traffic_signal_present  ... vehicle_condition  \
# count         195935                 193937  ...            202000
# unique             6                      8  ...                 4
# top      No Junction                     No  ...              Good
# freq           68499                 119324  ...             89115
#
#        overloading_status primary_cause secondary_cause  \
# count              191891        202000           62925
# unique                  4            13              13
# top        Not Applicable       Weather    Overspeeding
# freq               157225         26415            9761
#
#        emergency_services_called ambulance_called police_called  \
# count                     202000           202000        202000
# unique                         2                2             2
# top                           No               No            No
# freq                      105773           140345        120266
#
#        hospitalization_required accident_severity insurance_claim_filed
# count                    193928            202000                202000
# unique                        2                 4                     3
# top                          No             Minor                   Yes
# freq                     138207            111094                 95781
#
# [4 rows x 32 columns]

# %% [markdown]
# ### Data Type

# %%
df.dtypes
# Out:
# accident_id                      str
# accident_datetime                str
# state                            str
# district                         str
# area_type                        str
# latitude                     float64
# longitude                    float64
# road_type                        str
# road_condition                   str
# road_lighting                    str
# number_of_lanes              float64
# speed_limit_kmph             float64
# estimated_speed_kmph         float64
# junction_type                    str
# traffic_signal_present           str
# median_present                   str
# weather_condition                str
# visibility_km                float64
# temperature_c                float64
# rainfall_mm                  float64
# driver_age                   float64
# driver_gender                    str
# driving_experience_years     float64
# license_status                   str
# alcohol_involved                 str
# distraction_involved             str
# mobile_phone_used                str
# fatigue_involved                 str
# helmet_seatbelt_used             str
# vehicle_type                     str
# vehicle_age_years            float64
# vehicle_brand                    str
# vehicle_model                    str
# vehicle_condition                str
# overloading_status               str
# primary_cause                    str
# secondary_cause                  str
# emergency_services_called        str
# ambulance_called                 str
# police_called                    str
# response_time_minutes        float64
# hospitalization_required         str
# num_vehicles                   int64
# num_injuries                   int64
# num_fatalities                 int64
# accident_severity                str
# insurance_claim_filed            str
# insurance_claim_amount       float64
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# str        32
# float64    13
# int64       3
# Name: count, dtype: int64

# %%
numeric_cols = df.select_dtypes(include=np.number).columns
categorical_cols = df.select_dtypes(include=["object","string"]).columns
print("Numerical Columns : ",list(numeric_cols))
print("\nCategorical Columns : ",list(categorical_cols))
# Out:
# Numerical Columns :  ['latitude', 'longitude', 'number_of_lanes', 'speed_limit_kmph', 'estimated_speed_kmph', 'visibility_km', 'temperature_c', 'rainfall_mm', 'driver_age', 'driving_experience_years', 'vehicle_age_years', 'response_time_minutes', 'num_vehicles', 'num_injuries', 'num_fatalities', 'insurance_claim_amount']
#
# Categorical Columns :  ['accident_id', 'accident_datetime', 'state', 'district', 'area_type', 'road_type', 'road_condition', 'road_lighting', 'junction_type', 'traffic_signal_present', 'median_present', 'weather_condition', 'driver_gender', 'license_status', 'alcohol_involved', 'distraction_involved', 'mobile_phone_used', 'fatigue_involved', 'helmet_seatbelt_used', 'vehicle_type', 'vehicle_brand', 'vehicle_model', 'vehicle_condition', 'overloading_status', 'primary_cause', 'secondary_cause', 'emergency_services_called', 'ambulance_called', 'police_called', 'hospitalization_required', 'accident_severity', 'insurance_claim_filed']

# %% [markdown]
# ### Missing Values

# %%
missing_values = df.isnull().sum()
print(missing_values[missing_values > 0].sort_values(ascending=False))
# Out:
# secondary_cause             139075
# insurance_claim_amount      110904
# response_time_minutes       105773
# vehicle_model                43941
# vehicle_brand                38666
# driver_age                   28244
# vehicle_age_years            28244
# driving_experience_years     28244
# visibility_km                12121
# speed_limit_kmph             10112
# overloading_status           10109
# temperature_c                10097
# latitude                      9978
# longitude                     9978
# number_of_lanes               8086
# hospitalization_required      8072
# median_present                8069
# traffic_signal_present        8063
# junction_type                 6065
# road_lighting                 6064
# district                      6062
# driver_gender                 6058
# weather_condition             4038
# dtype: int64

# %%
missing_percentage=(df.isnull().sum() / len(df) * 100 ).sort_values(ascending=False)
missing_percentage[missing_percentage>0]
# Out:
# secondary_cause             68.849010
# insurance_claim_amount      54.902970
# response_time_minutes       52.362871
# vehicle_model               21.752970
# vehicle_brand               19.141584
# vehicle_age_years           13.982178
# driver_age                  13.982178
# driving_experience_years    13.982178
# visibility_km                6.000495
# speed_limit_kmph             5.005941
# overloading_status           5.004455
# temperature_c                4.998515
# latitude                     4.939604
# longitude                    4.939604
# number_of_lanes              4.002970
# hospitalization_required     3.996040
# median_present               3.994554
# traffic_signal_present       3.991584
# junction_type                3.002475
# road_lighting                3.001980
# district                     3.000990
# driver_gender                2.999010
# weather_condition            1.999010
# dtype: float64

# %%
missing_data = missing_percentage[missing_percentage>0]
plt.figure(figsize=(10,7))
plt.barh(missing_data.index, missing_data.values)
plt.title("Percentage of missing Values")
plt.xlabel("columns")
plt.ylabel("Missing percentage")
plt.tight_layout()
plt.show()

# %%
for col in categorical_cols:
    df[col] = df[col].astype(str).str.strip().str.lower()
    df[col] = df[col].replace("nan", np.nan)

# %%
df["weather_condition"] = df["weather_condition"].replace({"rain": "rainy"})
for col in ["traffic_signal_present", "median_present", "mobile_phone_used"]:
    df[col] = df[col].replace({"y": "yes", "1": "yes", "true": "yes","n": "no", "0": "no", "false": "no"})
print(df["weather_condition"].unique())
print(df["traffic_signal_present"].unique())
# Out:
# <ArrowStringArray>
# ['clear', nan, 'rainy', 'hazy', 'foggy', 'stormy']
# Length: 6, dtype: str
# <ArrowStringArray>
# ['yes', 'no', nan]
# Length: 3, dtype: str

# %%
na_cols = ["vehicle_brand", "vehicle_model", "secondary_cause"]
for col in na_cols:
    df[col] = df[col].fillna("not applicable")

# %%
num_missing_cols = df[numeric_cols].columns[df[numeric_cols].isnull().any()]
for col in num_missing_cols:
    df[col] = df[col].fillna(df[col].median())

# %%
categorical_missing_cols = df[categorical_cols].columns[df[categorical_cols].isnull().any()]
for col in categorical_missing_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
df.isnull().sum()
# Out:
# accident_id                  0
# accident_datetime            0
# state                        0
# district                     0
# area_type                    0
# latitude                     0
# longitude                    0
# road_type                    0
# road_condition               0
# road_lighting                0
# number_of_lanes              0
# speed_limit_kmph             0
# estimated_speed_kmph         0
# junction_type                0
# traffic_signal_present       0
# median_present               0
# weather_condition            0
# visibility_km                0
# temperature_c                0
# rainfall_mm                  0
# driver_age                   0
# driver_gender                0
# driving_experience_years     0
# license_status               0
# alcohol_involved             0
# distraction_involved         0
# mobile_phone_used            0
# fatigue_involved             0
# helmet_seatbelt_used         0
# vehicle_type                 0
# vehicle_age_years            0
# vehicle_brand                0
# vehicle_model                0
# vehicle_condition            0
# overloading_status           0
# primary_cause                0
# secondary_cause              0
# emergency_services_called    0
# ambulance_called             0
# police_called                0
# response_time_minutes        0
# hospitalization_required     0
# num_vehicles                 0
# num_injuries                 0
# num_fatalities               0
# accident_severity            0
# insurance_claim_filed        0
# insurance_claim_amount       0
# dtype: int64

# %% [markdown]
# ### Duplicate Values

# %%
df.duplicated().sum()
# Out:
# np.int64(980)

# %%
df = df.drop_duplicates()

# %%
df = df.drop_duplicates(subset="accident_id", keep="first")

# %%
print("Duplicate rows:", df.duplicated().sum())
print("Duplicate accident_id:", df["accident_id"].duplicated().sum())
print("Duplicate columns:", df.columns.duplicated().sum())
# Out:
# Duplicate rows: 0
# Duplicate accident_id: 0
# Duplicate columns: 0

# %% [markdown]
# ### Unique Values

# %%
df.nunique()
# Out:
# accident_id                  200000
# accident_datetime            199922
# state                            21
# district                         87
# area_type                         3
# latitude                     190119
# longitude                    190119
# road_type                         5
# road_condition                    5
# road_lighting                     2
# number_of_lanes                   5
# speed_limit_kmph                  9
# estimated_speed_kmph           1551
# junction_type                     6
# traffic_signal_present            2
# median_present                    2
# weather_condition                 5
# visibility_km                  1076
# temperature_c                   441
# rainfall_mm                    1157
# driver_age                       69
# driver_gender                     3
# driving_experience_years        551
# license_status                    5
# alcohol_involved                  3
# distraction_involved              3
# mobile_phone_used                 3
# fatigue_involved                  3
# helmet_seatbelt_used              3
# vehicle_type                      8
# vehicle_age_years               301
# vehicle_brand                    20
# vehicle_model                    50
# vehicle_condition                 4
# overloading_status                4
# primary_cause                    13
# secondary_cause                  13
# emergency_services_called         2
# ambulance_called                  2
# police_called                     2
# response_time_minutes         87796
# hospitalization_required          2
# num_vehicles                     24
# num_injuries                     14
# num_fatalities                   13
# accident_severity                 4
# insurance_claim_filed             3
# insurance_claim_amount        56004
# dtype: int64

# %%
# Negative values or impossible values
for col in numeric_cols:
    negative = (df[col] < 0).sum()
    if negative > 0:
        print(col,"->",negative,"negative values")
# Out:
# latitude -> 1169 negative values
# longitude -> 1189 negative values
# num_fatalities -> 80 negative values

# %%
df.loc[(df["driver_age"] < 0) | (df["driver_age"] > 100), "driver_age"] = np.nan
df.loc[df["num_fatalities"] < 0, "num_fatalities"] = np.nan
df.loc[(df["latitude"] < 6) | (df["latitude"] > 38), "latitude"] = np.nan
df.loc[(df["longitude"] < 68) | (df["longitude"] > 98), "longitude"] = np.nan
for col in ["driver_age", "num_fatalities", "latitude", "longitude"]:
    df[col] = df[col].fillna(df[col].median())

# %%
df[df["estimated_speed_kmph"] > df["speed_limit_kmph"]].shape[0]
# Out:
# 112716

# %%
df.loc[df["insurance_claim_filed"] != "yes", "insurance_claim_amount"] = 0
df["insurance_claim_amount"] = df["insurance_claim_amount"].fillna(df["insurance_claim_amount"].median())

# %%
df["state"] = df["state"].str.strip()
df["district"] = df["district"].str.strip()

# %% [markdown]
# ### Datetime

# %%
df["accident_datetime"] = pd.to_datetime(df["accident_datetime"])

# %%
df["accident_datetime"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["year"] = df["accident_datetime"].dt.year
df["month"] = df["accident_datetime"].dt.month
df["day"] = df["accident_datetime"].dt.day

# %% [markdown]
# ### Outliers

# %%
outlier_summary = {}
for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    count = ((df[col] < lower) | (df[col] > upper)).sum()
    outlier_summary[col] = count
outlier_summary
# Out:
# {'latitude': np.int64(0),
#  'longitude': np.int64(3256),
#  'number_of_lanes': np.int64(0),
#  'speed_limit_kmph': np.int64(7493),
#  'estimated_speed_kmph': np.int64(4894),
#  'visibility_km': np.int64(0),
#  'temperature_c': np.int64(0),
#  'rainfall_mm': np.int64(47410),
#  'driver_age': np.int64(2727),
#  'driving_experience_years': np.int64(2256),
#  'vehicle_age_years': np.int64(13373),
#  'response_time_minutes': np.int64(95262),
#  'num_vehicles': np.int64(13836),
#  'num_injuries': np.int64(2892),
#  'num_fatalities': np.int64(13238),
#  'insurance_claim_amount': np.int64(0)}

# %%
outlier_table = pd.DataFrame(outlier_summary.items(), columns=["Column", "Outlier Count"])
outlier_table.sort_values("Outlier Count", ascending=False)
# Out:
#                       Column  Outlier Count
# 11     response_time_minutes          95262
# 7                rainfall_mm          47410
# 12              num_vehicles          13836
# 10         vehicle_age_years          13373
# 14            num_fatalities          13238
# 3           speed_limit_kmph           7493
# 4       estimated_speed_kmph           4894
# 1                  longitude           3256
# 13              num_injuries           2892
# 8                 driver_age           2727
# 9   driving_experience_years           2256
# 0                   latitude              0
# 2            number_of_lanes              0
# 5              visibility_km              0
# 6              temperature_c              0
# 15    insurance_claim_amount              0

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
print("Missing values:", df.isnull().sum().sum())
print("Duplicate rows:", df.duplicated().sum())
print("Duplicate columns:",df.columns.duplicated().sum())
# Out:
# Rows: 200000
# Columns: 48
# Missing values: 0
# Duplicate rows: 0
# Duplicate columns: 0

# %%
df.columns
# Out:
# Index(['accident_id', 'accident_datetime', 'state', 'district', 'area_type',
#        'latitude', 'longitude', 'road_type', 'road_condition', 'road_lighting',
#        'number_of_lanes', 'speed_limit_kmph', 'estimated_speed_kmph',
#        'junction_type', 'traffic_signal_present', 'median_present',
#        'weather_condition', 'visibility_km', 'temperature_c', 'rainfall_mm',
#        'driver_age', 'driver_gender', 'driving_experience_years',
#        'license_status', 'alcohol_involved', 'distraction_involved',
#        'mobile_phone_used', 'fatigue_involved', 'helmet_seatbelt_used',
#        'vehicle_type', 'vehicle_age_years', 'vehicle_brand', 'vehicle_model',
#        'vehicle_condition', 'overloading_status', 'primary_cause',
#        'secondary_cause', 'emergency_services_called', 'ambulance_called',
#        'police_called', 'response_time_minutes', 'hospitalization_required',
#        'num_vehicles', 'num_injuries', 'num_fatalities', 'accident_severity',
#        'insurance_claim_filed', 'insurance_claim_amount'],
#       dtype='str')

# %% [markdown]
# ## Visualizations

# %%
plt.figure(figsize=(8,5))
plt.hist(df["driver_age"], bins=20, edgecolor="black")
plt.title("Distribution of Driver Age")
plt.xlabel("Driver Age")
plt.ylabel("Number of Drivers")
plt.show()

# %%
plt.figure(figsize=(9,5))
plt.hist(df["estimated_speed_kmph"], bins=25, edgecolor="darkblue")
plt.title("Distribution of Estimated Speed")
plt.xlabel("Speed")
plt.ylabel("Number of Accidents")
plt.show()

# %%
plt.figure(figsize=(7,7))
plt.pie(df["accident_severity"].value_counts().values,labels=df["accident_severity"].value_counts().index,
    autopct="%1.1f%%",
    startangle=90)
plt.title("Distribution of Accident Severity")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.boxplot(df["num_injuries"])
plt.title("Distribution of Number of Injuries")
plt.ylabel("Number of Injuries")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.barh(df["primary_cause"].value_counts().index, df["primary_cause"].value_counts().values)
plt.title(" Primary Causes of Accidents")
plt.xlabel("Number of Accidents")
plt.ylabel("Primary Cause")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7,7))
plt.pie(df["vehicle_type"].value_counts().values, labels=df["vehicle_type"].value_counts().index,autopct="%1.1f%%")
plt.title("Accidents by Vehicle Type",color="red")
plt.show()

# %%
yearly = df["year"].value_counts().sort_index()
plt.figure(figsize=(8,5))
plt.plot(yearly.index, yearly.values,marker="o")
plt.title("Accident by Year")
plt.xlabel("Year")
plt.ylabel("Number of Accidents")
plt.grid()
plt.show()

# %%
monthly = df["month"].value_counts().sort_index()
plt.figure(figsize=(8,5))
plt.plot(monthly.index,monthly.values,marker="o")
plt.title("Accidents by Month")
plt.xlabel("Month")
plt.ylabel("Number of Accidents")
plt.grid()
plt.show()

# %%
daily = df["day"].value_counts().sort_index()
plt.figure(figsize=(8,5))
plt.plot(daily.index, daily.values, marker="o")
plt.title("Accidents of Day")
plt.xlabel("Day")
plt.ylabel("Number of Accidents")
plt.grid()
plt.show()

# %%
road_severity = pd.crosstab(df["road_condition"], df["accident_severity"],normalize="index") * 100
road_severity.plot(kind="bar", stacked=True,figsize=(10,6))
plt.title("Road Condition vs Accident Severity")
plt.xlabel("Road Condition")
plt.ylabel("Percentage")
plt.legend(title="Severity")
plt.tight_layout()
plt.show()

# %%
alcohol_severity = pd.crosstab(df["alcohol_involved"], df["accident_severity"], normalize="index") * 100
alcohol_severity.plot(kind="bar",stacked=True, figsize=(8,5))
plt.title("Alcohol Involvement vs Accident Severity")
plt.xlabel("Alcohol Involved")
plt.ylabel("Percentage")
plt.legend(title="Severity")
plt.tight_layout()
plt.show()

# %%
vehicle_severity = pd.crosstab(df["vehicle_type"], df["accident_severity"], normalize="index") * 100
vehicle_severity.plot(kind="bar", stacked=True, figsize=(8,5))
plt.title("Vehicle Type vs Accident Severity")
plt.xlabel("Vehicle Type")
plt.ylabel("Percentage")
plt.xticks(rotation=45)
plt.legend(title="Severity")
plt.tight_layout()
plt.show()

# %%
df.boxplot(column="estimated_speed_kmph", by="accident_severity", figsize=(10,6))
plt.title("Estimated Speed by Accident Severity")
plt.xlabel("Accident Severity")
plt.ylabel("Estimated Speed ")
plt.show()

# %%
plt.figure(figsize=(9,6))
plt.scatter(df["estimated_speed_kmph"], df["num_injuries"], alpha=0.4)
plt.title("Estimated Speed vs Number of Injuries")
plt.xlabel("Estimated Speed (km/h)")
plt.ylabel("Number of Injuries")
plt.show()

# %%
numeric_df = df.select_dtypes(include=np.number)
correlation = numeric_df.corr()
correlation
# Out:
#                           latitude  longitude  number_of_lanes  \
# latitude                  1.000000   0.194327        -0.002684
# longitude                 0.194327   1.000000         0.001242
# number_of_lanes          -0.002684   0.001242         1.000000
# speed_limit_kmph          0.002378   0.004645         0.003027
# estimated_speed_kmph      0.000862   0.004040         0.002496
# visibility_km             0.000904  -0.003512         0.000089
# temperature_c             0.005587   0.002657        -0.001496
# rainfall_mm               0.003737   0.001148        -0.000413
# driver_age                0.000155  -0.001895         0.001715
# driving_experience_years  0.000171  -0.001644         0.000827
# vehicle_age_years        -0.000169  -0.000326        -0.001871
# response_time_minutes    -0.001676   0.003671         0.000449
# num_vehicles             -0.000047  -0.001386         0.001344
# num_injuries              0.002410   0.002367         0.002244
# num_fatalities            0.003370  -0.000945        -0.000879
# insurance_claim_amount    0.002940   0.002303         0.002683
# year                      0.000370  -0.000357         0.001607
# month                    -0.000723  -0.000796        -0.002181
# day                      -0.001696   0.000384         0.002086
#
#                           speed_limit_kmph  estimated_speed_kmph  \
# latitude                          0.002378              0.000862
# longitude                         0.004645              0.004040
# number_of_lanes                   0.003027              0.002496
# speed_limit_kmph                  1.000000              0.789427
# estimated_speed_kmph              0.789427              1.000000
# visibility_km                     0.005728              0.005251
# temperature_c                    -0.004117             -0.000053
# rainfall_mm                       0.001468             -0.000278
# driver_age                        0.002574              0.001397
# driving_experience_years          0.001456              0.000744
# vehicle_age_years                -0.005587             -0.002392
# response_time_minutes            -0.001054              0.005579
# num_vehicles                      0.004024              0.004935
# num_injuries                     -0.003688              0.056751
# num_fatalities                   -0.000964              0.049310
# insurance_claim_amount            0.001287             -0.001474
# year                             -0.000107              0.001786
# month                            -0.001558             -0.001715
# day                               0.001856              0.000979
#
#                           visibility_km  temperature_c  rainfall_mm  \
# latitude                       0.000904       0.005587     0.003737
# longitude                     -0.003512       0.002657     0.001148
# number_of_lanes                0.000089      -0.001496    -0.000413
# speed_limit_kmph               0.005728      -0.004117     0.001468
# estimated_speed_kmph           0.005251      -0.000053    -0.000278
# visibility_km                  1.000000      -0.105885    -0.334823
# temperature_c                 -0.105885       1.000000     0.092744
# rainfall_mm                   -0.334823       0.092744     1.000000
# driver_age                    -0.000508       0.001385     0.002093
# driving_experience_years      -0.000344       0.000910     0.000750
# vehicle_age_years              0.001673      -0.001684     0.001355
# response_time_minutes         -0.009784       0.000220     0.008402
# num_vehicles                  -0.002473      -0.008225    -0.002331
# num_injuries                  -0.107593       0.024415     0.064759
# num_fatalities                -0.087218       0.017465     0.052338
# insurance_claim_amount        -0.001387      -0.002425     0.001118
# year                           0.005179       0.031662     0.000815
# month                         -0.049748      -0.157998     0.043468
# day                            0.002024      -0.000070     0.002109
#
#                           driver_age  driving_experience_years  \
# latitude                    0.000155                  0.000171
# longitude                  -0.001895                 -0.001644
# number_of_lanes             0.001715                  0.000827
# speed_limit_kmph            0.002574                  0.001456
# estimated_speed_kmph        0.001397                  0.000744
# visibility_km              -0.000508                 -0.000344
# temperature_c               0.001385                  0.000910
# rainfall_mm                 0.002093                  0.000750
# driver_age                  1.000000                  0.942015
# driving_experience_years    0.942015                  1.000000
# vehicle_age_years           0.003142                  0.004311
# response_time_minutes      -0.002242                 -0.002097
# num_vehicles               -0.002428                 -0.001530
# num_injuries               -0.022657                 -0.020893
# num_fatalities             -0.020524                 -0.020109
# insurance_claim_amount      0.002327                  0.001807
# year                       -0.002130                 -0.002011
# month                      -0.000567                 -0.000994
# day                         0.005898                  0.006583
#
#                           vehicle_age_years  response_time_minutes  \
# latitude                          -0.000169              -0.001676
# longitude                         -0.000326               0.003671
# number_of_lanes                   -0.001871               0.000449
# speed_limit_kmph                  -0.005587              -0.001054
# estimated_speed_kmph              -0.002392               0.005579
# visibility_km                      0.001673              -0.009784
# temperature_c                     -0.001684               0.000220
# rainfall_mm                        0.001355               0.008402
# driver_age                         0.003142              -0.002242
# driving_experience_years           0.004311              -0.002097
# vehicle_age_years                  1.000000               0.003382
# response_time_minutes              0.003382               1.000000
# num_vehicles                      -0.002049               0.002113
# num_injuries                       0.012061               0.041356
# num_fatalities                     0.010897               0.040689
# insurance_claim_amount             0.008694              -0.001017
# year                              -0.000385              -0.000496
# month                              0.002135               0.002614
# day                                0.002030              -0.002251
#
#                           num_vehicles  num_injuries  num_fatalities  \
# latitude                     -0.000047      0.002410        0.003370
# longitude                    -0.001386      0.002367       -0.000945
# number_of_lanes               0.001344      0.002244       -0.000879
# speed_limit_kmph              0.004024     -0.003688       -0.000964
# estimated_speed_kmph          0.004935      0.056751        0.049310
# visibility_km                -0.002473     -0.107593       -0.087218
# temperature_c                -0.008225      0.024415        0.017465
# rainfall_mm                  -0.002331      0.064759        0.052338
# driver_age                   -0.002428     -0.022657       -0.020524
# driving_experience_years     -0.001530     -0.020893       -0.020109
# vehicle_age_years            -0.002049      0.012061        0.010897
# response_time_minutes         0.002113      0.041356        0.040689
# num_vehicles                  1.000000      0.049817        0.040172
# num_injuries                  0.049817      1.000000        0.211477
# num_fatalities                0.040172      0.211477        1.000000
# insurance_claim_amount       -0.000380      0.003025        0.005284
# year                         -0.002639     -0.000213        0.004407
# month                         0.001342      0.006487        0.007343
# day                           0.000791     -0.003084       -0.003532
#
#                           insurance_claim_amount      year     month       day
# latitude                                0.002940  0.000370 -0.000723 -0.001696
# longitude                               0.002303 -0.000357 -0.000796  0.000384
# number_of_lanes                         0.002683  0.001607 -0.002181  0.002086
# speed_limit_kmph                        0.001287 -0.000107 -0.001558  0.001856
# estimated_speed_kmph                   -0.001474  0.001786 -0.001715  0.000979
# visibility_km                          -0.001387  0.005179 -0.049748  0.002024
# temperature_c                          -0.002425  0.031662 -0.157998 -0.000070
# rainfall_mm                             0.001118  0.000815  0.043468  0.002109
# driver_age                              0.002327 -0.002130 -0.000567  0.005898
# driving_experience_years                0.001807 -0.002011 -0.000994  0.006583
# vehicle_age_years                       0.008694 -0.000385  0.002135  0.002030
# response_time_minutes                  -0.001017 -0.000496  0.002614 -0.002251
# num_vehicles                           -0.000380 -0.002639  0.001342  0.000791
# num_injuries                            0.003025 -0.000213  0.006487 -0.003084
# num_fatalities                          0.005284  0.004407  0.007343 -0.003532
# insurance_claim_amount                  1.000000 -0.000572 -0.000270  0.000795
# year                                   -0.000572  1.000000 -0.059678 -0.006763
# month                                  -0.000270 -0.059678  1.000000  0.008785
# day                                     0.000795 -0.006763  0.008785  1.000000

# %%
plt.figure(figsize=(9,6))
plt.imshow(correlation, cmap="coolwarm", aspect="auto")
plt.colorbar()
plt.xticks(range(len(correlation.columns)), correlation.columns, rotation=90)
plt.yticks(range(len(correlation.columns)), correlation.columns)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# #### Additional info

# %%
df["speed_violation"] = (df["estimated_speed_kmph"] > df["speed_limit_kmph"])
print("Speed violations:", df["speed_violation"].sum())
print("Percentage:",round(df["speed_violation"].mean() * 100,2),"%")
# Out:
# Speed violations: 112716
# Percentage: 56.36 %

# %%
emergency = pd.crosstab(df["emergency_services_called"], df["accident_severity"], normalize="index") * 100
print(emergency)
emergency.plot(kind="bar", stacked=True,figsize=(9,5))
plt.title("Emergency Services vs Accident Severity")
plt.xlabel("Emergency Services Called")
plt.ylabel("Percentage")
plt.tight_layout()
plt.show()
# Out:
# accident_severity             fatal      minor   moderate     severe
# emergency_services_called
# no                         0.385728  68.511605  25.884835   5.217831
# yes                        7.973715  40.144652  34.524422  17.357211

# %%
hospital = pd.crosstab(df["hospitalization_required"], df["accident_severity"], normalize="index") * 100
print(hospital)

hospital.plot(kind="bar",stacked=True,figsize=(9,5))
plt.title("Hospitalization Required vs Accident Severity")
plt.xlabel("Hospitalization Required")
plt.ylabel("Percentage")
plt.tight_layout()
plt.show()
# Out:
# accident_severity            fatal      minor   moderate     severe
# hospitalization_required
# no                         0.79199  67.388918  26.094252   5.724840
# yes                       12.42048  22.481196  40.251926  24.846398

# %%
weather_severity = pd.crosstab(df["weather_condition"], df["accident_severity"], normalize="index") * 100
weather_severity.plot(kind="bar", stacked=True, figsize=(12,6))
plt.title("Weather Condition vs Accident Severity")
plt.xlabel("Weather Condition")
plt.ylabel("Percentage")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(9,6))
plt.scatter(df["estimated_speed_kmph"], df["num_fatalities"],alpha=0.3)
plt.title("Estimated Speed vs Fatalities")
plt.xlabel("Estimated Speed (km/h)")
plt.ylabel("Number of Fatalities")
plt.show()

# %%
license_severity = pd.crosstab(df["license_status"], df["accident_severity"], normalize="index") * 100
license_severity.plot(kind="bar",stacked=True,figsize=(10,6))
plt.title("License Status vs Accident Severity")
plt.xlabel("License Status")
plt.ylabel("Percentage")
plt.show()
